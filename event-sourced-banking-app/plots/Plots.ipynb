# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Banking Application Plots

# %%
# 1000 Events
df = pd.DataFrame({
    'Snapshot Interval': [100, 300, 500, 1000, 1500],
    'Python': [0.367, 0.551, 0.827, 1.432, 1.465],
    'Ray': [1.18, 1.192, 1.198, 1.215, 1.241]
})
fig, ax1 = plt.subplots(figsize=(5, 5))
tidy = df.melt(id_vars='Snapshot Interval').rename(columns=str.title)
ax = sns.barplot(x='Snapshot Interval', y='Value', hue='Variable', data=tidy, ax=ax1)
ax.set(xlabel='Snapshot Intervals', ylabel='Mean Latency (s)')
ax.set_title("1000 Events")
sns.despine(fig)

# %%
# 3000 Events
df = pd.DataFrame({
    'Snapshot Interval': [100, 300, 500, 1000, 2000, 4000],
    'Python': [1.233, 1.83, 2.534, 4.275, 7.012, 11.85],
    'Ray': [6.325, 2.762, 2.756, 2.872, 3.02, 3.231]
})
fig, ax1 = plt.subplots(figsize=(5, 5))
tidy = df.melt(id_vars='Snapshot Interval').rename(columns=str.title)
ax = sns.barplot(x='Snapshot Interval', y='Value', hue='Variable', data=tidy, ax=ax1)
ax.set(xlabel='Snapshot Intervals', ylabel='Mean Latency (s)')
ax.set_title("3000 Events")
sns.despine(fig)

# %%
# 5000 Events
df = pd.DataFrame({
    'Snapshot Interval': [100, 300, 500, 1000, 2500, 4000, 6000],
    'Python': [2.565, 3.129, 4.43, 7.304, 16.75, 21.317, 31.67],
    'Ray': [13.21, 4.421, 4.342, 4.436, 5.013, 5.208, 6.109]
})
fig, ax1 = plt.subplots(figsize=(5, 5))
tidy = df.melt(id_vars='Snapshot Interval').rename(columns=str.title)
ax = sns.barplot(x='Snapshot Interval', y='Value', hue='Variable', data=tidy, ax=ax1)
ax.set(xlabel='Snapshot Intervals', ylabel='Mean Latency (s)')
ax.set_title("5000 Events")
sns.despine(fig)

# %%
# 8000 Events
df = pd.DataFrame({
    'Snapshot Interval': [100, 300, 500, 1000, 2500, 5000, 9000],
    'Python': [5.435, 6.154, 7.849, 12.648, 25.35, 43.057, 76.672],
    'Ray': [24.34038401, 8.764, 6.72, 6.884, 7.916, 8.413, 10.261]
})
fig, ax1 = plt.subplots(figsize=(5, 5))
tidy = df.melt(id_vars='Snapshot Interval').rename(columns=str.title)
ax = sns.barplot(x='Snapshot Interval', y='Value', hue='Variable', data=tidy, ax=ax1)
ax.set(xlabel='Snapshot Intervals', ylabel='Mean Latency (s)')
ax.set_title("8000 Events")
sns.despine(fig)

# %%
# 10000 Events
df = pd.DataFrame({
    'Snapshot Interval': [100, 300, 500, 1000, 2500, 5000, 7500, 12000],
    'Python': [8.044, 8.484, 10.682, 16.355, 34.48, 62.072, 74.892, 120.743],
    'Ray': [32.914, 12.24, 9.281, 8.533, 9.008, 11.194, 12.11, 15.726]
})
fig, ax1 = plt.subplots(figsize=(5, 5))
tidy = df.melt(id_vars='Snapshot Interval').rename(columns=str.title)
ax = sns.barplot(x='Snapshot Interval', y='Value', hue='Variable', data=tidy, ax=ax1)
ax.set(xlabel='Snapshot Intervals', ylabel='Mean Latency (s)')
ax.set_title("10000 Events")
sns.despine(fig)
